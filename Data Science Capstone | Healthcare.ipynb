# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("health care diabetes.csv")

# %% [markdown]
# ### Week 1

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### Descriptive Analysis

# %%
data.isnull().any()
#no null values
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#Glucose, BloodPressure, SkinThickness, Insulin and BMI have a min value of 0
#which dosen't make sense On these columns and thus indicates missing value.

# %%
data['Glucose'].plot.hist()
data['Glucose'].mean()
# Out:
# 120.89453125

# %%
# i will replace 0 values with the mean value cuz the histgram shows 
# that most observation have Glucose level between 100 - 125 

data['Glucose']=data['Glucose'].replace(0,data['Glucose'].mean())

# %%
data['BloodPressure'].plot.hist()
data['BloodPressure'].mean()
# Out:
# 69.10546875

# %%
# i will replace 0 values with the mean value cuz the histgram shows 
# that most observation have BloodPressure between 60-80
data['BloodPressure']=data['BloodPressure'].replace(0,data['BloodPressure'].mean())

# %%
data['SkinThickness'].plot.hist()
data['SkinThickness'].mean()
# Out:
# 20.536458333333332

# %%
# i will replace 0 values with the mean value cuz the histgram shows 
# that most observation have SkinThickness between 20 -30
data['SkinThickness']=data['SkinThickness'].replace(0,data['SkinThickness'].mean())

# %%
data['Insulin'].plot.hist()
data['Insulin'].mean()
# Out:
# 79.79947916666667

# %%
# i will replace 0 values with the mean value cuz the histgram shows 
# that most observation have Insulin level between 80 - 100
data['Insulin']=data['Insulin'].replace(0,data['Insulin'].mean())

# %%
data['BMI'].plot.hist()
data['BMI'].mean()
# Out:
# 32.45080515543617

# %%
# i will replace 0 values with the mean value cuz the histgram shows 
# that most observation have BMI level between 30-40
data['BMI']=data['BMI'].replace(0,data['BMI'].mean())

# %%
data.describe() # there are no 0 min values
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.681605      72.254807      26.606479  118.660163
# std       3.369578   30.436016      12.115932       9.631241   93.080358
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      20.536458   79.799479
# 50%       3.000000  117.000000      72.000000      23.000000   79.799479
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450805                  0.471876   33.240885    0.348958
# std      6.875374                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ### There are integer and float data type variables in this dataset. Create a count (frequency) plot describing the data types and the count of variables.

# %%
data.dtypes.value_counts().plot(kind='bar')

# %% [markdown]
# ### Week 2

# %% [markdown]
# ### Checking Data balance

# %%
sns.countplot(data['Outcome'])
data['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# ### The data is balanced so we don't need to preform any sampling method to balance the dataset

# %%
# scatter charts between the pair of variables
sns.pairplot(data)
plt.title('Scatter charts between variables')
# Out:
# Text(0.5, 1, 'Scatter charts between variables')

# %%
# correlation analysis
data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.127964       0.208984       0.013376
# Glucose                      0.127964  1.000000       0.219666       0.160766
# BloodPressure                0.208984  0.219666       1.000000       0.134155
# SkinThickness                0.013376  0.160766       0.134155       1.000000
# Insulin                     -0.018082  0.396597       0.010926       0.240361
# BMI                          0.021546  0.231478       0.281231       0.535703
# DiabetesPedigreeFunction    -0.033523  0.137106       0.000371       0.154961
# Age                          0.544341  0.266600       0.326740       0.026423
# Outcome                      0.221898  0.492908       0.162986       0.175026
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.018082  0.021546                 -0.033523
# ...

# %% [markdown]
# ### Glucose and BMI has impact on the outcome
# ### BMI and Skinthickness has positive correlation
# ### Pregnancies and age has positive correlation

# %%
#create correlation heat map
sns.heatmap(data.corr())

# %% [markdown]
# ### Week 3

# %% [markdown]
#  ### Model building

# %%
x=data.iloc[:,:-1].values
y=data.iloc[:,-1].values
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (614, 8)
# (154, 8)
# (614,)
# (154,)

# %%
data.shape
# Out:
# (768, 9)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=25) 
#Using 25 Neighbors just as thumb rule sqrt of observation
knn_model.fit(x_train,y_train)
knn_pred=knn_model.predict(x_test)

# %%
print("Accuracy Score of the KNN Model:")
print(metrics.accuracy_score(y_test,knn_pred))
print("Classification Report:")
print(metrics.classification_report(y_test,knn_pred))
print("ROC Curve")
knn_prob=knn_model.predict_proba(x_test)
knn_prob1=knn_prob[:,1]
fpr,tpr,thresh=metrics.roc_curve(y_test,knn_prob1)
roc_auc_knn=metrics.auc(fpr,tpr)
plt.figure(dpi=80)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_knn)
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
# Accuracy Score of the KNN Model:
# 0.7792207792207793
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.85       107
#            1       0.66      0.57      0.61        47
#
#     accuracy                           0.78       154
#    macro avg       0.74      0.72      0.73       154
# weighted avg       0.77      0.78      0.77       154
#
# ROC Curve

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# %%
#preform Logistic Regression
lr_model = LogisticRegression(C=0.01) 
lr_model.fit(x_train,y_train)
# Out:
# /Users/hanan/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#make prediction 
lr_pred=lr_model.predict(x_test)

# %%
print("Accuracy Score of the Logistic Regression Model is :")
print(metrics.accuracy_score(y_test,lr_pred))
# Out:
# Accuracy Score of the Logistic Regression Model is :
# 0.6818181818181818

# %%
print("Classification Report:")
print(metrics.classification_report(y_test,lr_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.79      0.77       107
#            1       0.48      0.45      0.46        47
#
#     accuracy                           0.68       154
#    macro avg       0.62      0.62      0.62       154
# weighted avg       0.68      0.68      0.68       154

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
# predict probabilities
print("\n","ROC Curve")
lr_prob=lr_model.predict_proba(x_test)
lr_prob1=lr_prob[:,1]
fpr,tpr,thresh=metrics.roc_curve(y_test,lr_prob1)
roc_auc_lr=metrics.auc(fpr,tpr)
plt.figure(dpi=80)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_lr)
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
#  ROC Curve

# %% [markdown]
# ### Accuracy of  the KNN model  is better than Logistic Regression model

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=1000,random_state=0)
rf_model.fit(x_train,y_train)
rf_pred=rf_model.predict(x_test)
print("Model Validation ==>\n")
print("Accuracy Score of Logistic Regression Model::")
print(metrics.accuracy_score(y_test,rf_pred))
print("\n","Classification Report::")
print(metrics.classification_report(y_test,rf_pred),'\n')
print("\n","ROC Curve")
rf_prob=rf_model.predict_proba(x_test)
rf_prob1=rf_prob[:,1]
fpr,tpr,thresh=metrics.roc_curve(y_test,rf_prob1)
roc_auc_rf=metrics.auc(fpr,tpr)
plt.figure(dpi=80)
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_rf)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
# Model Validation ==>
#
# Accuracy Score of Logistic Regression Model::
# 0.8246753246753247
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87       107
#            1       0.71      0.72      0.72        47
#
#     accuracy                           0.82       154
#    macro avg       0.79      0.80      0.79       154
# weighted avg       0.83      0.82      0.83       154
#
#
#
#  ROC Curve

# %% [markdown]
# ### Accuracy of  the Random Forest Classifier model  is better than the KNN Model and the   Logistic Regression model
